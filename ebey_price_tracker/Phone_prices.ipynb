# %%
import requests
from bs4 import BeautifulSoup
import csv

# %%
url = "https://www.ebay.com/b/Cell-Phones-Smartphones/9355?Brand=Apple&Color=Purple&Model=Apple%2520iPhone%252014%2520Pro%2520Max&rt=nc"
res = requests.get(url)

# %%
soup = BeautifulSoup(res.text,'lxml')

# %%
with open('output.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    
    # Write headers to the CSV file
    writer.writerow(['Title', 'Price', 'Shipping Cost', 'Number of Bids', 'Ending Time', 'Rating Stars', 'Number of Reviews'])
    
    # Find all listings
    lists = soup.find_all('li', class_='s-item s-item--large')
    
    for item in lists:
        # Find the title of the listing
        listing_title_elem = item.find('h3', class_='s-item__title')
        listing_title = listing_title_elem.text.strip() if listing_title_elem else 'N/A'

        # Find the rating and reviews section
        rating_reviews_div = item.find('div', class_='b-rating s-item__reviews')
        
        if rating_reviews_div:
            # Extract the rating (stars)
            rating_stars_div = rating_reviews_div.find('div', class_='star-rating b-rating__rating-star')
            stars_count = len(rating_stars_div.find_all('svg')) if rating_stars_div else 'N/A'
            
            # Extract the number of reviews
            rating_count_span = rating_reviews_div.find('span', class_='b-rating__rating-count')
            reviews_count = rating_count_span.text.strip('()') if rating_count_span else 'N/A'
        else:
            stars_count = 'N/A'
            reviews_count = 'N/A'

        # Find price, shipping cost, number of bids, and ending time
        price_span = item.find('span', class_='s-item__price')
        price = price_span.text.strip() if price_span else 'N/A'

        shipping_cost_span = item.find('span', class_='s-item__shipping')
        shipping_cost = shipping_cost_span.text.strip() if shipping_cost_span else 'N/A'

        bids_span = item.find('span', class_='s-item__bidCount')
        number_of_bids = bids_span.text if bids_span else 'N/A'

        ending_time_parent = item.find('span', class_='s-item__time-left')
        ending_time = ending_time_parent.text.strip() if ending_time_parent else 'N/A'

        # Print or process any of the extracted data here
        print(f"Title: {listing_title}")
        print(f"Price: {price}")
        print(f"Shipping Cost: {shipping_cost}")
        print(f"Number of Bids: {number_of_bids}")
        print(f"Ending Time: {ending_time}")
        print(f"Rating Stars: {stars_count}")
        print(f"Number of Reviews: {reviews_count}")
        print("----------------------------------")
        
        # Write the row to the CSV file
        writer.writerow([
            listing_title,
            price,
            shipping_cost,
            number_of_bids,
            ending_time,
            stars_count,
            reviews_count
        ])

# File will be automatically closed after exiting the 'with' block
# Out:
# Title: New ListingApple iPhone 14 Pro Max - 128 GB - Purple (Unlocked) (Single SIM)
# Price: $500.00
# Shipping Cost: $34.66 shipping
# Number of Bids: 5 bids
# Ending Time: 6d 14h
# Rating Stars: 5
# Number of Reviews: 10)10 product ratings - Apple iPhone 14 Pro Max - 128 GB - Purple (Unlocked) (Single SIM
# ----------------------------------
# Title: APPLE IPHONE 14 PRO MAX 128GB 256GB 512GB 1TB (FACTORY UNLOCKED) ALL COLOR ✤O/B✤
# Price: $948.95 to $969.95
# Shipping Cost: $57.70 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 2)2 product ratings - APPLE IPHONE 14 PRO MAX 128GB 256GB 512GB 1TB (FACTORY UNLOCKED) ALL COLOR ✤O/B✤
# ----------------------------------
# Title: Apple iPhone 14 Pro Max 1TB Unlocked AT&T T-Mobile Verizon Very Good Condition
# Price: $869.95
# Shipping Cost: $54.75 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 2)2 product ratings - Apple iPhone 14 Pro Max 1TB Unlocked AT&T T-Mobile Verizon Very Good Condition
# ----------------------------------
# Title: Apple iPhone 14 Pro Max -  Space Grey - FOR PARTS
# Price: $297.20
# Shipping Cost: $62.00 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: N/A
# Number of Reviews: N/A
# ----------------------------------
# Title: Apple iPhone 14 Pro Max 128GB A2651 5G Unlocked - Good
# Price: $699.99
# Shipping Cost: $49.74 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 10)10 product ratings - Apple iPhone 14 Pro Max 128GB A2651 5G Unlocked - Good
# ----------------------------------
# Title: Apple iPhone 14 Pro Max - 128GB 256GB 512GB 1TB - All Colors - Good Condition
# Price: $629.00 to $829.00
# Shipping Cost: $53.54 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 4)4 product ratings - Apple iPhone 14 Pro Max - 128GB 256GB 512GB 1TB - All Colors - Good Condition
# ----------------------------------
# Title: Apple iPhone 14 Pro Max - 128GB 256GB 512GB 1TB - All Colors - Very Good
# Price: $680.00 to $800.00
# Shipping Cost: $49.15 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 12)12 product ratings - Apple iPhone 14 Pro Max - 128GB 256GB 512GB 1TB - All Colors - Very Good
# ----------------------------------
# Title: Apple iPhone 14 Pro Max 256GB Network Unlocked TESTED 100% Battery Purple
# Price: $789.99
# Shipping Cost: $41.45 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 6)6 product ratings - Apple iPhone 14 Pro Max 256GB Network Unlocked TESTED 100% Battery Purple
# ----------------------------------
# Title: New ListingApple iphone 14 PRO MAX A2651 Factory Unlocked 512GB GSM CDMA Phone
# Price: $945.99
# Shipping Cost: $57.00 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: N/A
# Number of Reviews: N/A
# ----------------------------------
# Title: iPhone 14 Pro Max - Factory Unlocked - 256GB - Purple - Good
# Price: $769.00
# Shipping Cost: $51.77 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 9)9 product ratings - iPhone 14 Pro Max - Factory Unlocked - 256GB - Purple - Good
# ----------------------------------
# Title: OPEN Box Apple iphone 14 PRO MAX Factory Unlocked 256GB GSM CDMA All colors
# Price: $909.99
# Shipping Cost: $55.93 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 6)6 product ratings - OPEN Box Apple iphone 14 PRO MAX Factory Unlocked 256GB GSM CDMA All colors
# ----------------------------------
# Title: Apple iPhone 14 Pro Max A2651 Unlocked 128GB Deep Purple Good
# Price: $789.99
# Shipping Cost: $52.39 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 3)3 product ratings - Apple iPhone 14 Pro Max A2651 Unlocked 128GB Deep Purple Good
# ----------------------------------
# Title: Apple iPhone 14 Pro Max - 128GB - Deep Purple - (AT&T) - Good
# Price: $909.99
# Shipping Cost: $55.93 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 3)3 product ratings - Apple iPhone 14 Pro Max - 128GB - Deep Purple - (AT&T) - Good
# ----------------------------------
# Title: For iPhone 14 13 12 Mini Pro Max Mag Safe Magnetic Case Cover Screen Protector
# Price: $3.28 to $11.86
# Shipping Cost: $29.35 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: N/A
# Number of Reviews: N/A
# ----------------------------------
# Title: Apple iPhone 14 Pro Max 128GB A2651 5G (AT&T) Only - Very Good
# Price: $629.99
# Shipping Cost: $47.67 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 3)3 product ratings - Apple iPhone 14 Pro Max 128GB A2651 5G (AT&T) Only - Very Good
# ----------------------------------
# Title: Apple iPhone 14 Pro Max 1TB Deep Purple Unlocked Excellent Condition
# Price: $959.99
# Shipping Cost: $57.41 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 6)6 product ratings - Apple iPhone 14 Pro Max 1TB Deep Purple Unlocked Excellent Condition
# ----------------------------------
# Title: Apple iPhone 14 Pro Max A2894 Unlocked 128GB Deep Purple Good
# Price: $769.99
# Shipping Cost: $51.80 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 3)3 product ratings - Apple iPhone 14 Pro Max A2894 Unlocked 128GB Deep Purple Good
# ----------------------------------
# Title: Apple iPhone 14 Pro Max A2651 Unlocked 512GB Deep Purple Good
# Price: $849.99
# Shipping Cost: $54.16 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 2)2 product ratings - Apple iPhone 14 Pro Max A2651 Unlocked 512GB Deep Purple Good
# ----------------------------------
# Title: Apple iPhone 14 Pro Max A16 128GB 256GB 512GB 1TB Unlocked ⭐Tracking⭐
# Price: $1,395.49 to $2,079.49
# Shipping Cost: $25.49 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 6)6 product ratings - Apple iPhone 14 Pro Max A16 128GB 256GB 512GB 1TB Unlocked ⭐Tracking⭐
# ----------------------------------
# Title: iPhone 14 Pro Max 128GB AT&T Locked Deep Purple - Very Good Condition
# Price: $860.00
# Shipping Cost: $54.46 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: N/A
# Number of Reviews: N/A
# ----------------------------------
# Title: Apple iPhone 14 Pro Max - 128GB - Deep Purple (AT&T)
# Price: $1,200.00
# Shipping Cost: $69.40 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 3)3 product ratings - Apple iPhone 14 Pro Max - 128GB - Deep Purple (AT&T
# ----------------------------------
# Title: Apple iPhone 14 Pro Max 256GB AT&T Locked Excellent Condition
# Price: $819.95
# Shipping Cost: $53.28 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 7)7 product ratings - Apple iPhone 14 Pro Max 256GB AT&T Locked Excellent Condition
# ----------------------------------
# Title: New Apple iPhone 14 Pro Max 6.7"120Hz Real Dual Sim Apple A16 48MP Phone ByFedEx
# Price: $1,379.69 to $2,027.69
# Shipping Cost: $42.00 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: N/A
# Number of Reviews: N/A
# ----------------------------------
# Title: Apple iPhone 14 Pro Max - A2651 - 128 GB Unlocked DEEP PURPLE - MINT CONDITION
# Price: $865.00
# Shipping Cost: $54.61 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 10)10 product ratings - Apple iPhone 14 Pro Max - A2651 - 128 GB Unlocked DEEP PURPLE - MINT CONDITION
# ----------------------------------
# Title: Apple iPhone 14 Pro Max - 256GB - Purple - (AT&T) - Good
# Price: $959.99
# Shipping Cost: $57.41 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 7)7 product ratings - Apple iPhone 14 Pro Max - 256GB - Purple - (AT&T) - Good
# ----------------------------------
# Title: Apple iPhone 14 Pro Max 128GB 6.7" 120Hz Real Dual Sim A2896 48MP Phone By FedEx
# Price: $1,379.64
# Shipping Cost: $42.00 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: N/A
# Number of Reviews: N/A
# ----------------------------------
# Title: Apple iPhone 14 Pro Max 512GB 6.7" 120Hz Real Dual Sim A2896 48MP Phone By FedEx
# Price: $1,797.63
# Shipping Cost: $42.00 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: N/A
# Number of Reviews: N/A
# ----------------------------------
# Title: Apple iPhone 14 Pro Max 1TB 6.7" 120Hz Real Dual Sim A2896 48MP CN FREESHIP
# Price: $2,027.29
# Shipping Cost: $42.00 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 2)2 product ratings - Apple iPhone 14 Pro Max 1TB 6.7" 120Hz Real Dual Sim A2896 48MP CN FREESHIP
# ----------------------------------
# Title: Apple iPhone 14 Pro Max 1TB 6.7" 120Hz Real Dual Sim A2896 48MP Phone By FedEx
# Price: $2,027.62
# Shipping Cost: $42.00 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: N/A
# Number of Reviews: N/A
# ----------------------------------
# Title: Apple iPhone 14 Pro Max - 256GB - Purple - (AT&T) - Very Good
# Price: $989.99
# Shipping Cost: $58.29 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 7)7 product ratings - Apple iPhone 14 Pro Max - 256GB - Purple - (AT&T) - Very Good
# ----------------------------------
# Title: Apple iPhone 14 Pro Max A2651 Unlocked 128GB Deep Purple Very Good
# Price: $819.99
# Shipping Cost: $53.28 shipping
# Number of Bids: N/A
# Ending Time: N/A
# Rating Stars: 5
# Number of Reviews: 3)3 product ratings - Apple iPhone 14 Pro Max A2651 Unlocked 128GB Deep Purple Very Good
# ----------------------------------
